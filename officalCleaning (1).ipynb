# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import os

# %%
os.getcwd()
os.chdir('E:\SEM1\DAB103\Project')

# %% [markdown]
# # ***1) Accidents due to drunken driving till 2018***

# %%
df1 = pd.read_csv('accidents due to drunken driving till 2018.csv',index_col=0)

# %%
df1.head()
# Out:
#               States/UTs  2016  2017  2018
# Sl.No
# 1         Andhra Pradesh   128  2064  1345
# 2      Arunachal Pradesh    15    19    55
# 3                  Assam   352   373   377
# 4                  Bihar   593     0    10
# 5           Chhattisgarh   145    86   216

# %%
df1.tail()
# Out:
#         States/UTs   2016   2017   2018
# Sl.No
# 33     Daman & Diu      7     12      8
# 34           Delhi    164    124    333
# 35     Lakshadweep      0      0      0
# 36      Puducherry     82      5     14
# Total        Total  14894  14071  12018

# %%
df1 = df1.rename(columns = {'States/UTs':'Region', '2016':'drunk_drv16', '2017':'drunk_drv17', '2018':'drunk_drv18'})
df1.head()
# Out:
#                   Region  drunk_drv16  drunk_drv17  drunk_drv18
# Sl.No
# 1         Andhra Pradesh          128         2064         1345
# 2      Arunachal Pradesh           15           19           55
# 3                  Assam          352          373          377
# 4                  Bihar          593            0           10
# 5           Chhattisgarh          145           86          216

# %%
# drop(self, labels, axis, index, columns, level, inplace, errors)
df1 = df1.drop(labels = 'Total')

# %%
df1['Region'].replace(['A & N Islands','D & N Haveli'], ['Andaman & Nicobar Islands','Dadra & Nagar Haveli'], inplace = True)

# %%
df1
# Out:
#                           Region  drunk_drv16  drunk_drv17  drunk_drv18
# Sl.No
# 1                 Andhra Pradesh          128         2064         1345
# 2              Arunachal Pradesh           15           19           55
# 3                          Assam          352          373          377
# 4                          Bihar          593            0           10
# 5                   Chhattisgarh          145           86          216
# 6                            Goa            3           10            9
# 7                        Gujarat           64           65          106
# 8                        Haryana          529          180          474
# 9               Himachal Pradesh           72          214          322
# 10               Jammu & Kashmir           47            1           20
# 11                     Jharkhand          543          801          517
# 12                     Karnataka          396          169          139
# ...

# %% [markdown]
# # ***2) Fund allocation for state roads and SH till 2018***

# %%
df2 = pd.read_csv('fund allocation for state roads and SH till 2018.csv',index_col=0)

# %%
df2.head()
# Out:
#                    State/UT  2015-16 - Accrual  2015-16 - Release  \
# Category
# State        Andhra Pradesh             136.13             178.13
# State     Arunachal Pradesh              52.68              20.53
# State                 Assam              57.86              46.34
# State                 Bihar              80.88              80.88
# State          Chhattisgarh              98.73              84.13
#
#           2016-17 - Accrual  2016-17 - Release  2017-18 - Accrual  \
# Category
# State                348.72             347.17             316.45
# State                131.11              56.69             122.47
# State                144.08              94.03             134.77
# State                200.46             169.70             190.11
# State                247.30              97.12             231.16
#
#           2017-18 - Release
# Category
# State                331.48
# State                132.74
# State                 48.80
# ...

# %%
df2.tail()
# Out:
#                              State/UT  2015-16 - Accrual  2015-16 - Release  \
# Category
# Union Territory  Dadra & Nagar Haveli               1.33                NaN
# Union Territory           Daman & Diu               0.99                NaN
# Union Territory                 Delhi              24.75                NaN
# Union Territory           Lakshadweep               0.00                NaN
# Union Territory            Puducherry               4.95                4.9
#
#                  2016-17 - Accrual  2016-17 - Release  2017-18 - Accrual  \
# Category
# Union Territory               3.87               0.00               3.78
# Union Territory               2.70               0.00               2.32
# Union Territory              64.12               5.54              58.19
# Union Territory               0.23               0.00               0.00
# Union Territory              10.68              32.80              11.64
#
#                  2017-18 - Release
# Category
# ...

# %%
df2
# Out:
#                                   State/UT  2015-16 - Accrual  \
# Category
# State                       Andhra Pradesh             136.13
# State                    Arunachal Pradesh              52.68
# State                                Assam              57.86
# State                                Bihar              80.88
# State                         Chhattisgarh              98.73
# State                                  Goa               6.62
# State                              Gujarat             177.02
# State                              Haryana              79.45
# State                     Himachal Pradesh              40.59
# State                      Jammu & Kashmir             143.93
# State                            Jharkhand              65.63
# State                            Karnataka             178.18
# State                               Kerala              59.88
# State                       Madhya Pradesh             226.82
# ...

# %%
df2 = df2.rename(columns = {'State/UT':'Region', '2015-16 - Accrual':'State_Fund_Accrual2016', '2015-16 - Release':'State_Fund_Release2016', '2016-17 - Accrual':'State_Fund_Accrual2017', '2016-17 - Release':'State_Fund_Release2017', '2017-18 - Accrual':'State_Fund_Accrual2018', '2017-18 - Release':'State_Fund_Release2018'})
df2.head()
# Out:
#                      Region  State_Fund_Accrual2016  State_Fund_Release2016  \
# Category
# State        Andhra Pradesh                  136.13                  178.13
# State     Arunachal Pradesh                   52.68                   20.53
# State                 Assam                   57.86                   46.34
# State                 Bihar                   80.88                   80.88
# State          Chhattisgarh                   98.73                   84.13
#
#           State_Fund_Accrual2017  State_Fund_Release2017  \
# Category
# State                     348.72                  347.17
# State                     131.11                   56.69
# State                     144.08                   94.03
# State                     200.46                  169.70
# State                     247.30                   97.12
#
#           State_Fund_Accrual2018  State_Fund_Release2018
# Category
# State                     316.45                  331.48
# ...

# %%
df2.tail()
# Out:
#                                Region  State_Fund_Accrual2016  \
# Category
# Union Territory  Dadra & Nagar Haveli                    1.33
# Union Territory           Daman & Diu                    0.99
# Union Territory                 Delhi                   24.75
# Union Territory           Lakshadweep                    0.00
# Union Territory            Puducherry                    4.95
#
#                  State_Fund_Release2016  State_Fund_Accrual2017  \
# Category
# Union Territory                     NaN                    3.87
# Union Territory                     NaN                    2.70
# Union Territory                     NaN                   64.12
# Union Territory                     NaN                    0.23
# Union Territory                     4.9                   10.68
#
#                  State_Fund_Release2017  State_Fund_Accrual2018  \
# Category
# Union Territory                    0.00                    3.78
# ...

# %%
df2=df2.fillna(0)

# %%
df2.tail()
# Out:
#                                Region  State_Fund_Accrual2016  \
# Category
# Union Territory  Dadra & Nagar Haveli                    1.33
# Union Territory           Daman & Diu                    0.99
# Union Territory                 Delhi                   24.75
# Union Territory           Lakshadweep                    0.00
# Union Territory            Puducherry                    4.95
#
#                  State_Fund_Release2016  State_Fund_Accrual2017  \
# Category
# Union Territory                     0.0                    3.87
# Union Territory                     0.0                    2.70
# Union Territory                     0.0                   64.12
# Union Territory                     0.0                    0.23
# Union Territory                     4.9                   10.68
#
#                  State_Fund_Release2017  State_Fund_Accrual2018  \
# Category
# Union Territory                    0.00                    3.78
# ...

# %%
df2['Region'].replace(['Odisha'],['Orissa'], inplace = True)

# %%
df2
# Out:
#                                     Region  State_Fund_Accrual2016  \
# Category
# State                       Andhra Pradesh                  136.13
# State                    Arunachal Pradesh                   52.68
# State                                Assam                   57.86
# State                                Bihar                   80.88
# State                         Chhattisgarh                   98.73
# State                                  Goa                    6.62
# State                              Gujarat                  177.02
# State                              Haryana                   79.45
# State                     Himachal Pradesh                   40.59
# State                      Jammu & Kashmir                  143.93
# State                            Jharkhand                   65.63
# State                            Karnataka                  178.18
# State                               Kerala                   59.88
# ...

# %%
df = pd.merge(df1,df2, on='Region')

# %%
df
# Out:
#                        Region  drunk_drv16  drunk_drv17  drunk_drv18  \
# 0              Andhra Pradesh          128         2064         1345
# 1           Arunachal Pradesh           15           19           55
# 2                       Assam          352          373          377
# 3                       Bihar          593            0           10
# 4                Chhattisgarh          145           86          216
# 5                         Goa            3           10            9
# 6                     Gujarat           64           65          106
# 7                     Haryana          529          180          474
# 8            Himachal Pradesh           72          214          322
# 9             Jammu & Kashmir           47            1           20
# 10                  Jharkhand          543          801          517
# 11                  Karnataka          396          169          139
# 12                     Kerala          133          133          157
# ...

# %%
df.shape
# Out:
# (36, 10)

# %% [markdown]
# # ***3) Funds for National highway construction till 2019***

# %%
df3 = pd.read_csv('funds for national highway till 2019.csv',index_col=0)

# %%
df3.head()
# Out:
#      State/UT/Schemes/Agency  2016-17  2017-18  2018-19
# S No
# 1             Andhra Pradesh  2010.31  1781.18  2260.26
# 2          Arunachal Pradesh   100.00    62.05    90.00
# 3                      Assam   177.44   308.05   414.00
# 4                      Bihar  1362.64  1689.90  1598.31
# 5               Chhattisgarh  1553.30  1107.93  1831.32

# %%
df3 = df3.rename(columns = {'State/UT/Schemes/Agency':'Region', '2016-17':'NHfund_const2017', '2017-18':'NHfund_const2018', '2018-19':'NHfund_const2019'})
df3.head()
# Out:
#                  Region  NHfund_const2017  NHfund_const2018  NHfund_const2019
# S No
# 1        Andhra Pradesh           2010.31           1781.18           2260.26
# 2     Arunachal Pradesh            100.00             62.05             90.00
# 3                 Assam            177.44            308.05            414.00
# 4                 Bihar           1362.64           1689.90           1598.31
# 5          Chhattisgarh           1553.30           1107.93           1831.32

# %%
df3.tail()
# Out:
#                                                         Region  \
# S No
# 42           Left Wing Extremism affected Area (LWE) includ...
# 43                             Externally Aided Projects (EAP)
# 44                                Reserve/unallocated in above
# 45                                   IEBR / Borrowings by NHAI
# Grand Total                                        Grand Total
#
#              NHfund_const2017  NHfund_const2018  NHfund_const2019
# S No
# 42                     760.00           1050.00            905.00
# 43                      59.38            316.00            183.00
# 44                       0.44             12.59            500.00
# 45                   59279.00          59279.00          62000.00
# Grand Total         100605.60         109453.84         130083.56

# %%
df3
# Out:
#                                                         Region  \
# S No
# 1                                               Andhra Pradesh
# 2                                            Arunachal Pradesh
# 3                                                        Assam
# 4                                                        Bihar
# 5                                                 Chhattisgarh
# 6                                                          Goa
# 7                                                      Gujarat
# 8                                                      Haryana
# 9                                             Himachal Pradesh
# 10                                             Jammu & Kashmir
# 11                                                   Jharkhand
# 12                                                   Karnataka
# 13                                                      Kerala
# 14                                              Madhya Pradesh
# ...

# %%
# drop row
df3 = df3.drop(labels = ['Grand Total'])

# %%
# Replace row value. Can be used if there is any spelling mistake in Region column
df3['Region'].replace(['Odisha'], ['Orissa'], inplace = True)

# %%
# adding new row. Use when any region is not present in dataframe.
df3 = df3.append({'Region':'Dadra & Nagar Haveli'}, ignore_index = True)

# %%
df3 = df3.fillna(0)

# %%
df3 = df3.append({'Region':'Daman & Diu'}, ignore_index = True)

# %%
df3 = df3.append({'Region':'Lakshadweep'}, ignore_index = True)

# %%
df3 = df3.fillna(0)

# %%
df3
# Out:
#                                                Region  NHfund_const2017  \
# 0                                      Andhra Pradesh           2010.31
# 1                                   Arunachal Pradesh            100.00
# 2                                               Assam            177.44
# 3                                               Bihar           1362.64
# 4                                        Chhattisgarh           1553.30
# 5                                                 Goa            400.00
# 6                                             Gujarat            251.87
# 7                                             Haryana            150.00
# 8                                    Himachal Pradesh            210.95
# 9                                     Jammu & Kashmir             40.06
# 10                                          Jharkhand            200.00
# 11                                          Karnataka            783.52
# ...

# %%
df = pd.merge(df,df3, on = 'Region')
df.head()
# Out:
#               Region  drunk_drv16  drunk_drv17  drunk_drv18  \
# 0     Andhra Pradesh          128         2064         1345
# 1  Arunachal Pradesh           15           19           55
# 2              Assam          352          373          377
# 3              Bihar          593            0           10
# 4       Chhattisgarh          145           86          216
#
#    State_Fund_Accrual2016  State_Fund_Release2016  State_Fund_Accrual2017  \
# 0                  136.13                  178.13                  348.72
# 1                   52.68                   20.53                  131.11
# 2                   57.86                   46.34                  144.08
# 3                   80.88                   80.88                  200.46
# 4                   98.73                   84.13                  247.30
#
#    State_Fund_Release2017  State_Fund_Accrual2018  State_Fund_Release2018  \
# 0                  347.17                  316.45                  331.48
# ...

# %%
df.shape
# Out:
# (36, 13)

# %% [markdown]
# # ***4) Funds for National Highway maintenance till 2020***

# %%
df4 = pd.read_csv('funds for NH maintainance till 2020.csv',index_col=0)

# %%
df4.head()
# Out:
#          States/UTs/Agency  2016-17 - Alloc.  2016-17 - Expd.  \
# Sl. No.
# 1           Andhra Pradesh            129.87           123.10
# 2        Arunachal Pradesh             36.63            28.87
# 3                    Assam            136.50            97.52
# 4                    Bihar            104.77            88.68
# 5             Chhattisgarh             51.00            36.05
#
#          2017-18 - Alloc.  2017-18 - Expd.  2018-19 - Alloc.  2018-19 - Expd.  \
# Sl. No.
# 1                   83.52            77.02             87.98            18.06
# 2                   42.67            36.31             34.10            15.97
# 3                  122.63            89.28             48.33            11.33
# 4                  121.68            97.29             38.86            20.92
# 5                   28.17            21.95             28.59             8.24
#
#          2019-20 - Alloc.  2019-20 - Expd.
# Sl. No.
# 1                   39.39            13.28
# ...

# %%
df4
# Out:
#                                          States/UTs/Agency  2016-17 - Alloc.  \
# Sl. No.
# 1                                           Andhra Pradesh            129.87
# 2                                        Arunachal Pradesh             36.63
# 3                                                    Assam            136.50
# 4                                                    Bihar            104.77
# 5                                             Chhattisgarh             51.00
# 6                                                      Goa             34.13
# 7                                                  Gujarat            121.69
# 8                                                  Haryana             56.31
# 9                                         Himachal Pradesh             94.85
# 10                                         Jammu & Kashmir             10.34
# 11                                               Jharkhand             91.26
# ...

# %%
df4=df4.fillna(0)

# %%
df4.tail()
# Out:
#                                          States/UTs/Agency  2016-17 - Alloc.  \
# Sl. No.
# 35                                              Puducherry              1.21
# 36            National Highways Authority of India (NHAI)*            100.00
# 37       National Highways & Infrastructure Development...             52.00
# 38                        Border Roads Organization (BRO)*            115.00
# 39                                Bridge Management System              1.80
#
#          2016-17 - Expd.  2017-18 - Alloc.  2017-18 - Expd.  2018-19 - Alloc.  \
# Sl. No.
# 35                  1.02              1.14             0.36              1.08
# 36                100.00            575.00           575.00            272.19
# 37                 52.00            125.00           125.00            100.00
# 38                114.75            135.00           134.78            115.00
# 39                  0.88              2.69             2.68              0.00
#
# ...

# %%
df4 = df4.rename(columns = {'States/UTs/Agency':'Region', '2016-17 - Alloc.':'NHM_Alloc17', '2016-17 - Expd.':'NHM_Expd17', 
                            '2017-18 - Alloc.':'NHM_Alloc18', '2017-18 - Expd.':'NHM_Expd18', 
                            '2018-19 - Alloc.':'NHM_Alloc19', '2018-19 - Expd.':'NHM_Expd19',
                            '2019-20 - Alloc.':'NHM_Alloc20', '2019-20 - Expd.':'NHM_Expd20'})
df4.head()
# Out:
#                     Region  NHM_Alloc17  NHM_Expd17  NHM_Alloc18  NHM_Expd18  \
# Sl. No.
# 1           Andhra Pradesh       129.87      123.10        83.52       77.02
# 2        Arunachal Pradesh        36.63       28.87        42.67       36.31
# 3                    Assam       136.50       97.52       122.63       89.28
# 4                    Bihar       104.77       88.68       121.68       97.29
# 5             Chhattisgarh        51.00       36.05        28.17       21.95
#
#          NHM_Alloc19  NHM_Expd19  NHM_Alloc20  NHM_Expd20
# Sl. No.
# 1              87.98       18.06        39.39       13.28
# 2              34.10       15.97        13.58        0.00
# 3              48.33       11.33        33.55        0.00
# 4              38.86       20.92        24.71        0.02
# 5              28.59        8.24        12.39        0.00

# %%
df4.tail()
# Out:
#                                                     Region  NHM_Alloc17  \
# Sl. No.
# 35                                              Puducherry         1.21
# 36            National Highways Authority of India (NHAI)*       100.00
# 37       National Highways & Infrastructure Development...        52.00
# 38                        Border Roads Organization (BRO)*       115.00
# 39                                Bridge Management System         1.80
#
#          NHM_Expd17  NHM_Alloc18  NHM_Expd18  NHM_Alloc19  NHM_Expd19  \
# Sl. No.
# 35             1.02         1.14        0.36         1.08        0.32
# 36           100.00       575.00      575.00       272.19      272.19
# 37            52.00       125.00      125.00       100.00      100.00
# 38           114.75       135.00      134.78       115.00      114.81
# 39             0.88         2.69        2.68         0.00        0.00
#
#          NHM_Alloc20  NHM_Expd20
# Sl. No.
# 35               1.1         0.0
# ...

# %%
df4['Region'].replace(['Odisha'],['Orissa'], inplace = True)

# %%
df4['Region'].replace(['Dadar & Nagar Haveli'],['Dadra & Nagar Haveli'], inplace = True)

# %%
df4 = df4.append({'Region':'Lakshadweep'}, ignore_index = True)

# %%
df4 = df4.fillna(0)

# %%
df4
# Out:
#                                                Region  NHM_Alloc17  \
# 0                                      Andhra Pradesh       129.87
# 1                                   Arunachal Pradesh        36.63
# 2                                               Assam       136.50
# 3                                               Bihar       104.77
# 4                                        Chhattisgarh        51.00
# 5                                                 Goa        34.13
# 6                                             Gujarat       121.69
# 7                                             Haryana        56.31
# 8                                    Himachal Pradesh        94.85
# 9                                     Jammu & Kashmir        10.34
# 10                                          Jharkhand        91.26
# 11                                          Karnataka       204.53
# 12                                             Kerala       115.46
# ...

# %%
df = pd.merge(df,df4, on = 'Region')

# %%
df.head()
# Out:
#               Region  drunk_drv16  drunk_drv17  drunk_drv18  \
# 0     Andhra Pradesh          128         2064         1345
# 1  Arunachal Pradesh           15           19           55
# 2              Assam          352          373          377
# 3              Bihar          593            0           10
# 4       Chhattisgarh          145           86          216
#
#    State_Fund_Accrual2016  State_Fund_Release2016  State_Fund_Accrual2017  \
# 0                  136.13                  178.13                  348.72
# 1                   52.68                   20.53                  131.11
# 2                   57.86                   46.34                  144.08
# 3                   80.88                   80.88                  200.46
# 4                   98.73                   84.13                  247.30
#
#    State_Fund_Release2017  State_Fund_Accrual2018  State_Fund_Release2018  \
# 0                  347.17                  316.45                  331.48
# ...

# %%
df.shape
# Out:
# (36, 21)

# %% [markdown]
# # ***5) National highway projects under construction as of 31march 2019***

# %%
df5=pd.read_csv('NH projects under construction as on 31march 2019.csv',index_col=0)
df5.head()
# Out:
#                State/UT  Total Ongoing Works - No.  \
# S No
# 1        Andhra Pradesh                         63
# 2          A & N Island                          8
# 3     Arunachal Pradesh                         48
# 4                 Assam                         66
# 5                 Bihar                         66
#
#       Total Ongoing Works - Length (km)  Total Ongoing Works - Cost (Rs in Cr)
# S No
# 1                               2199.65                               29415.19
# 2                                262.35                                1813.74
# 3                               1227.28                               11939.11
# 4                               1505.99                               12873.37
# 5                               2447.21                               29040.18

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, 1 to Total
# Data columns (total 4 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   State/UT                               33 non-null     object
#  1   Total Ongoing Works - No.              33 non-null     int64
#  2   Total Ongoing Works - Length (km)      33 non-null     float64
#  3   Total Ongoing Works - Cost (Rs in Cr)  33 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 1.3+ KB

# %%
df5.tail()
# Out:
#             State/UT  Total Ongoing Works - No.  \
# S No
# 29           Tripura                          8
# 30     Uttar Pradesh                         67
# 31       Uttarakhand                         61
# 32       West Bengal                         51
# Total          Total                       1495
#
#        Total Ongoing Works - Length (km)  \
# S No
# 29                                201.03
# 30                               3637.42
# 31                               1277.47
# 32                               1309.34
# Total                           52947.71
#
#        Total Ongoing Works - Cost (Rs in Cr)
# S No
# 29                                   1374.93
# 30                                  55388.84
# 31                                  18144.91
# 32                                  21811.81
# Total                              617641.26

# %%
df5 = df5.rename(columns = {'State/UT':'Region', 'Total Ongoing Works - No.':'NH_Projects', 
                            'Total Ongoing Works - Length (km)':'NH_Projects_length',
                            'Total Ongoing Works - Cost (Rs in Cr)':'NH_Project_cost'})
df5.head()
# Out:
#                  Region  NH_Projects  NH_Projects_length  NH_Project_cost
# S No
# 1        Andhra Pradesh           63             2199.65         29415.19
# 2          A & N Island            8              262.35          1813.74
# 3     Arunachal Pradesh           48             1227.28         11939.11
# 4                 Assam           66             1505.99         12873.37
# 5                 Bihar           66             2447.21         29040.18

# %%
df5
# Out:
#                   Region  NH_Projects  NH_Projects_length  NH_Project_cost
# S No
# 1         Andhra Pradesh           63             2199.65         29415.19
# 2           A & N Island            8              262.35          1813.74
# 3      Arunachal Pradesh           48             1227.28         11939.11
# 4                  Assam           66             1505.99         12873.37
# 5                  Bihar           66             2447.21         29040.18
# 6           Chhattisgarh           63             2761.94         16367.82
# 7                  Delhi           13              343.51         16251.87
# 8                    Goa           16               97.41          5450.15
# 9                Gujarat           53             1827.40         30255.65
# 10               Haryana           39             1501.59         18785.22
# 11      Himachal Pradesh           44              818.40         10199.64
# ...

# %%
df5 = df5.drop(labels = ['Total'])

# %%
df5
# Out:
#                  Region  NH_Projects  NH_Projects_length  NH_Project_cost
# S No
# 1        Andhra Pradesh           63             2199.65         29415.19
# 2          A & N Island            8              262.35          1813.74
# 3     Arunachal Pradesh           48             1227.28         11939.11
# 4                 Assam           66             1505.99         12873.37
# 5                 Bihar           66             2447.21         29040.18
# 6          Chhattisgarh           63             2761.94         16367.82
# 7                 Delhi           13              343.51         16251.87
# 8                   Goa           16               97.41          5450.15
# 9               Gujarat           53             1827.40         30255.65
# 10              Haryana           39             1501.59         18785.22
# 11     Himachal Pradesh           44              818.40         10199.64
# 12      Jammu & Kashmir           24              538.44         22559.77
# ...

# %%
df5['Region'].replace(['A & N Island','Odisha'],['Andaman & Nicobar Islands','Orissa'], inplace = True)

# %%
df5
# Out:
#                          Region  NH_Projects  NH_Projects_length  \
# S No
# 1                Andhra Pradesh           63             2199.65
# 2     Andaman & Nicobar Islands            8              262.35
# 3             Arunachal Pradesh           48             1227.28
# 4                         Assam           66             1505.99
# 5                         Bihar           66             2447.21
# 6                  Chhattisgarh           63             2761.94
# 7                         Delhi           13              343.51
# 8                           Goa           16               97.41
# 9                       Gujarat           53             1827.40
# 10                      Haryana           39             1501.59
# 11             Himachal Pradesh           44              818.40
# 12              Jammu & Kashmir           24              538.44
# 13                    Jharkhand           43             1044.09
# ...

# %%
df5 = df5.append({'Region':'Chandigarh'}, ignore_index = True)
df5.tail()
# Out:
#            Region  NH_Projects  NH_Projects_length  NH_Project_cost
# 28        Tripura          8.0              201.03          1374.93
# 29  Uttar Pradesh         67.0             3637.42         55388.84
# 30    Uttarakhand         61.0             1277.47         18144.91
# 31    West Bengal         51.0             1309.34         21811.81
# 32     Chandigarh          NaN                 NaN              NaN

# %%
df5 = df5.append({'Region':'Dadra & Nagar Haveli'}, ignore_index = True)
df5.tail()
# Out:
#                   Region  NH_Projects  NH_Projects_length  NH_Project_cost
# 29         Uttar Pradesh         67.0             3637.42         55388.84
# 30           Uttarakhand         61.0             1277.47         18144.91
# 31           West Bengal         51.0             1309.34         21811.81
# 32            Chandigarh          NaN                 NaN              NaN
# 33  Dadra & Nagar Haveli          NaN                 NaN              NaN

# %%
df5 = df5.append({'Region':'Daman & Diu'}, ignore_index = True)
df5.tail()
# Out:
#                   Region  NH_Projects  NH_Projects_length  NH_Project_cost
# 30           Uttarakhand         61.0             1277.47         18144.91
# 31           West Bengal         51.0             1309.34         21811.81
# 32            Chandigarh          NaN                 NaN              NaN
# 33  Dadra & Nagar Haveli          NaN                 NaN              NaN
# 34           Daman & Diu          NaN                 NaN              NaN

# %%
df5 = df5.append({'Region':'Lakshadweep'}, ignore_index = True)
df5.tail()
# Out:
#                   Region  NH_Projects  NH_Projects_length  NH_Project_cost
# 31           West Bengal         51.0             1309.34         21811.81
# 32            Chandigarh          NaN                 NaN              NaN
# 33  Dadra & Nagar Haveli          NaN                 NaN              NaN
# 34           Daman & Diu          NaN                 NaN              NaN
# 35           Lakshadweep          NaN                 NaN              NaN

# %%
df5 = df5.fillna(0)
df5.tail()
# Out:
#                   Region  NH_Projects  NH_Projects_length  NH_Project_cost
# 31           West Bengal         51.0             1309.34         21811.81
# 32            Chandigarh          0.0                0.00             0.00
# 33  Dadra & Nagar Haveli          0.0                0.00             0.00
# 34           Daman & Diu          0.0                0.00             0.00
# 35           Lakshadweep          0.0                0.00             0.00

# %%
df = pd.merge(df,df5, on = 'Region')
df.head()
# Out:
#               Region  drunk_drv16  drunk_drv17  drunk_drv18  \
# 0     Andhra Pradesh          128         2064         1345
# 1  Arunachal Pradesh           15           19           55
# 2              Assam          352          373          377
# 3              Bihar          593            0           10
# 4       Chhattisgarh          145           86          216
#
#    State_Fund_Accrual2016  State_Fund_Release2016  State_Fund_Accrual2017  \
# 0                  136.13                  178.13                  348.72
# 1                   52.68                   20.53                  131.11
# 2                   57.86                   46.34                  144.08
# 3                   80.88                   80.88                  200.46
# 4                   98.73                   84.13                  247.30
#
#    State_Fund_Release2017  State_Fund_Accrual2018  State_Fund_Release2018  \
# 0                  347.17                  316.45                  331.48
# ...

# %%
df.shape
# Out:
# (36, 24)

# %% [markdown]
# # ***6) Persons killed in road accidents***

# %%
df6=pd.read_csv('persons killed in road accidents.csv',index_col=0)
df6.head()
# Out:
#                 States/UTs  2015  2016  2017
# Sl. No.
# 1           Andhra Pradesh  8297  8541  8060
# 2        Arunachal Pradesh   127   149   110
# 3                    Assam  2397  2572  2783
# 4                    Bihar  5421  4901  5554
# 5             Chhattisgarh  4082  3908  4136

# %%
df6
# Out:
#                         States/UTs    2015    2016    2017
# Sl. No.
# 1                   Andhra Pradesh    8297    8541    8060
# 2                Arunachal Pradesh     127     149     110
# 3                            Assam    2397    2572    2783
# 4                            Bihar    5421    4901    5554
# 5                     Chhattisgarh    4082    3908    4136
# 6                              Goa     311     336     328
# 7                          Gujarat    8119    8136    7289
# 8                          Haryana    4879    5024    5120
# 9                 Himachal Pradesh    1096    1271    1203
# 10                 Jammu & Kashmir     917     958     926
# 11                       Jharkhand    2893    3027    3256
# 12                       Karnataka   10856   11133   10609
# 13                          Kerala    4196    4287    4131
# 14                  Madhya Pradesh    9314    9646   10177
# 15                     Maharashtra   13212   12935   12264
# ...

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37 entries, 1 to Total
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   States/UTs  36 non-null     object
#  1   2015        37 non-null     int64
#  2   2016        37 non-null     int64
#  3   2017        37 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 1.4+ KB

# %%
df6.tail()
# Out:
#           States/UTs    2015    2016    2017
# Sl. No.
# 33       Daman & Diu      42      38      36
# 34             Delhi    1622    1591    1584
# 35       Lakshadweep       0       1       0
# 36        Puducherry     235     244     233
# Total            NaN  146133  150785  147913

# %%
df6['States/UTs'].fillna('X', inplace=True)

# %%
df6.tail()
# Out:
#           States/UTs    2015    2016    2017
# Sl. No.
# 33       Daman & Diu      42      38      36
# 34             Delhi    1622    1591    1584
# 35       Lakshadweep       0       1       0
# 36        Puducherry     235     244     233
# Total              X  146133  150785  147913

# %%
df6 = df6.rename(columns = {'States/UTs':'Region', '2015':'Fatal_Accidents_2015', '2016':'Fatal_Accidents_2016', '2017':'Fatal_Accidenst_2017'})
df6.head()
# Out:
#                     Region  Fatal_Accidents_2015  Fatal_Accidents_2016  \
# Sl. No.
# 1           Andhra Pradesh                  8297                  8541
# 2        Arunachal Pradesh                   127                   149
# 3                    Assam                  2397                  2572
# 4                    Bihar                  5421                  4901
# 5             Chhattisgarh                  4082                  3908
#
#          Fatal_Accidenst_2017
# Sl. No.
# 1                        8060
# 2                         110
# 3                        2783
# 4                        5554
# 5                        4136

# %%
df6
# Out:
#                             Region  Fatal_Accidents_2015  \
# Sl. No.
# 1                   Andhra Pradesh                  8297
# 2                Arunachal Pradesh                   127
# 3                            Assam                  2397
# 4                            Bihar                  5421
# 5                     Chhattisgarh                  4082
# 6                              Goa                   311
# 7                          Gujarat                  8119
# 8                          Haryana                  4879
# 9                 Himachal Pradesh                  1096
# 10                 Jammu & Kashmir                   917
# 11                       Jharkhand                  2893
# 12                       Karnataka                 10856
# 13                          Kerala                  4196
# 14                  Madhya Pradesh                  9314
# 15                     Maharashtra                 13212
# ...

# %%
df6['Region'].replace(['Odisha'],['Orissa'], inplace = True)

# %%
df6
# Out:
#                             Region  Fatal_Accidents_2015  \
# Sl. No.
# 1                   Andhra Pradesh                  8297
# 2                Arunachal Pradesh                   127
# 3                            Assam                  2397
# 4                            Bihar                  5421
# 5                     Chhattisgarh                  4082
# 6                              Goa                   311
# 7                          Gujarat                  8119
# 8                          Haryana                  4879
# 9                 Himachal Pradesh                  1096
# 10                 Jammu & Kashmir                   917
# 11                       Jharkhand                  2893
# 12                       Karnataka                 10856
# 13                          Kerala                  4196
# 14                  Madhya Pradesh                  9314
# 15                     Maharashtra                 13212
# ...

# %%
df6 = df6.drop(labels = ['Total'])
df6.tail()
# Out:
#                        Region  Fatal_Accidents_2015  Fatal_Accidents_2016  \
# Sl. No.
# 32       Dadra & Nagar Haveli                    42                    46
# 33                Daman & Diu                    42                    38
# 34                      Delhi                  1622                  1591
# 35                Lakshadweep                     0                     1
# 36                 Puducherry                   235                   244
#
#          Fatal_Accidenst_2017
# Sl. No.
# 32                         43
# 33                         36
# 34                       1584
# 35                          0
# 36                        233

# %%
df = pd.merge(df6,df, on='Region')
df.head()
# Out:
#               Region  Fatal_Accidents_2015  Fatal_Accidents_2016  \
# 0     Andhra Pradesh                  8297                  8541
# 1  Arunachal Pradesh                   127                   149
# 2              Assam                  2397                  2572
# 3              Bihar                  5421                  4901
# 4       Chhattisgarh                  4082                  3908
#
#    Fatal_Accidenst_2017  drunk_drv16  drunk_drv17  drunk_drv18  \
# 0                  8060          128         2064         1345
# 1                   110           15           19           55
# 2                  2783          352          373          377
# 3                  5554          593            0           10
# 4                  4136          145           86          216
#
#    State_Fund_Accrual2016  State_Fund_Release2016  State_Fund_Accrual2017  \
# 0                  136.13                  178.13                  348.72
# ...

# %%
df.shape
# Out:
# (36, 27)

# %% [markdown]
# # 7) Registered vehicles per 100km

# %%
df7=pd.read_csv('registered vehicles per 100km.csv',index_col=0)
df7.head()
# Out:
#                   2004-2014        State/UT.1  2005-2015
# State/UT
# Bihar                  18.7           Tripura       14.5
# Manipur                14.0  Himachal Pradesh       13.6
# Meghalaya              13.0             Bihar       13.5
# Himachal Pradesh       12.9           Mizoram       12.5
# Tripura                12.9       Uttarakhand       12.3

# %%
df7
# Out:
#                            2004-2014                 State/UT.1  2005-2015
# State/UT
# Bihar                           18.7                    Tripura       14.5
# Manipur                         14.0           Himachal Pradesh       13.6
# Meghalaya                       13.0                      Bihar       13.5
# Himachal Pradesh                12.9                    Mizoram       12.5
# Tripura                         12.9                Uttarakhand       12.3
# Karnataka                       12.9               Chhattisgarh       12.1
# Andaman & Nicobar Islands       12.8                     Kerala       11.9
# Mizoram                         12.6                      Assam       11.9
# Chhattisgarh                    12.3                     Odisha       11.8
# Uttarakhand                     12.3              Uttar Pradesh       11.4
# Kerala                          12.1                  Rajasthan       11.3
# ...

# %%
df7 = df7.rename(columns = {'State/UT':'Region1','2004-2014':'Vehicles_From2004-2014','State/UT.1':'Region','2005-2015':'Vehicles_From2005-2015'})
df7.head()
# Out:
#                   Vehicles_From2004-2014            Region  \
# State/UT
# Bihar                               18.7           Tripura
# Manipur                             14.0  Himachal Pradesh
# Meghalaya                           13.0             Bihar
# Himachal Pradesh                    12.9           Mizoram
# Tripura                             12.9       Uttarakhand
#
#                   Vehicles_From2005-2015
# State/UT
# Bihar                               14.5
# Manipur                             13.6
# Meghalaya                           13.5
# Himachal Pradesh                    12.5
# Tripura                             12.3

# %%
df7.tail()
# Out:
#              Vehicles_From2004-2014       Region  Vehicles_From2005-2015
# State/UT
# Daman & Diu                     7.1        Delhi                     7.8
# Delhi                           6.9  Daman & Diu                     7.1
# Nagaland                        6.3     Nagaland                     6.8
# Jharkhand                       3.5    Jharkhand                     4.3
# Chandigarh                      0.7   Chandigarh                     0.9

# %%
df7 = df7.append({'Region':'Andhra Pradesh'}, ignore_index = True)

# %%
df7 = df7.append({'Region':'Punjab'}, ignore_index = True)

# %%
df7 = df7.append({'Region':'Telangana'}, ignore_index = True)

# %%
df7 = df7.append({'Region':'Arunachal Pradesh'}, ignore_index = True)

# %%
df7=df7.fillna(0)

# %%
df7['Region'].replace(['Odisha'],['Orissa'], inplace = True)

# %%
rgvdf.shape
# Out:
# (32, 3)

# %% [markdown]
# #  8) Road Accidents by districts 2019 TamilNadu

# %%
tn=pd.read_csv('road_accidents_by_districts_2019_TN.csv',index_col=0)
tn.head()
# Out:
#          City/District  Total Number of Accidents (2018)  \
# S.No
# 1         Chennai City                              7580
# 2      Coimbatore City                              1136
# 3         Madurai City                               962
# 4           Salem City                               902
# 5     Tirunelveli City                               367
#
#       Number of Persons Injured (2018)  Number of Persons Killed (2018)
# S.No
# 1                                 7438                             1260
# 2                                 1140                              162
# 3                                  945                              153
# 4                                  997                              142
# 5                                  370                               60

# %%
tn
# Out:
#                          City/District  Total Number of Accidents (2018)  \
# S.No
# 1                         Chennai City                              7580
# 2                      Coimbatore City                              1136
# 3                         Madurai City                               962
# 4                           Salem City                               902
# 5                     Tirunelveli City                               367
# 6                        Tiruppur City                               751
# 7                 Tiruchirappalli City                               602
# 8                             Ariyalur                               642
# 9                           Coimbatore                              2055
# 10                           Cuddalore                              3493
# 11                          Dharmapuri                              1447
# 12                            Dindigul                              1840
# ...

# %%
tn.tail()
# Out:
#                          City/District  Total Number of Accidents (2018)  \
# S.No
# 37                          Villupuram                              3262
# 38                        Virudhunagar                              1054
# 39             Railway Police, Chennai                                 6
# 40     Railway Police, Tiruchirappalli                                 3
# Total                            Total                             63920
#
#        Number of Persons Injured (2018)  Number of Persons Killed (2018)
# S.No
# 37                                 4405                              538
# 38                                 1321                              238
# 39                                    7                                3
# 40                                    4                                0
# Total                             74537                            12216

# %%
tn=tn.drop(labels='Total')

# %%
tn
# Out:
#                         City/District  Total Number of Accidents (2018)  \
# S.No
# 1                        Chennai City                              7580
# 2                     Coimbatore City                              1136
# 3                        Madurai City                               962
# 4                          Salem City                               902
# 5                    Tirunelveli City                               367
# 6                       Tiruppur City                               751
# 7                Tiruchirappalli City                               602
# 8                            Ariyalur                               642
# 9                          Coimbatore                              2055
# 10                          Cuddalore                              3493
# 11                         Dharmapuri                              1447
# 12                           Dindigul                              1840
# ...

# %% [markdown]
# # ***9) Road-Accidents on national highway 2015 to 2018***

# %%
df9=pd.read_csv('Road-Accidents on national highway-2015to 2018.csv',index_col=0)
df9.head()
# Out:
#                 States/UTs  2015  2016  2017  2018 - Number  2018 - Rank
# Sl. No.
# 1           Andhra Pradesh  8477  8171  8544           8122          7.0
# 2        Arunachal Pradesh   113    95    88             89         30.0
# 3                    Assam  3353  3478  3274           3963         16.0
# 4                    Bihar  3227  3138  3883           4016         13.0
# 5             Chhattisgarh  4058  4042  3701           3995         15.0

# %%
df9
# Out:
#                         States/UTs    2015    2016    2017  2018 - Number  \
# Sl. No.
# 1                   Andhra Pradesh    8477    8171    8544           8122
# 2                Arunachal Pradesh     113      95      88             89
# 3                            Assam    3353    3478    3274           3963
# 4                            Bihar    3227    3138    3883           4016
# 5                     Chhattisgarh    4058    4042    3701           3995
# 6                              Goa    1784    1438    1470           1425
# 7                          Gujarat    4897    4617    4333           3997
# 8                          Haryana    3509    3818    3785           4358
# 9                 Himachal Pradesh    1211    1475    1460           1455
# 10                 Jammu & Kashmir    1953    2122    2139           2118
# 11                       Jharkhand    2007    1935    1828           1616
# ...

# %%
df9.tail()
# Out:
#           States/UTs    2015    2016    2017  2018 - Number  2018 - Rank
# Sl. No.
# 33       Daman & Diu       6       0       9              0         34.0
# 34             Delhi     897     723     755            783         23.0
# 35       Lakshadweep       0       0       0              0         34.0
# 36        Puducherry     763     874     937            771         24.0
# Total          Total  142268  142359  141466         140843          NaN

# %%
df9 = df9.rename(columns = {'States/UTs': 'Region','2015':'Road_accidents_NH_2015','2016':'Road_accidents_NH_2016','2017':'Road_accidents_NH_2017','2018 - Number':'Road_accidents_NH_2018','2018 - Rank':'Rank_in_2018'})
df9.head()
# Out:
#                     Region  Road_accidents_NH_2015  Road_accidents_NH_2016  \
# Sl. No.
# 1           Andhra Pradesh                    8477                    8171
# 2        Arunachal Pradesh                     113                      95
# 3                    Assam                    3353                    3478
# 4                    Bihar                    3227                    3138
# 5             Chhattisgarh                    4058                    4042
#
#          Road_accidents_NH_2017  Road_accidents_NH_2018  Rank_in_2018
# Sl. No.
# 1                          8544                    8122           7.0
# 2                            88                      89          30.0
# 3                          3274                    3963          16.0
# 4                          3883                    4016          13.0
# 5                          3701                    3995          15.0

# %%
df9
# Out:
#                             Region  Road_accidents_NH_2015  \
# Sl. No.
# 1                   Andhra Pradesh                    8477
# 2                Arunachal Pradesh                     113
# 3                            Assam                    3353
# 4                            Bihar                    3227
# 5                     Chhattisgarh                    4058
# 6                              Goa                    1784
# 7                          Gujarat                    4897
# 8                          Haryana                    3509
# 9                 Himachal Pradesh                    1211
# 10                 Jammu & Kashmir                    1953
# 11                       Jharkhand                    2007
# 12                       Karnataka                   12705
# 13                          Kerala                    9442
# 14                  Madhya Pradesh                   11988
# 15                     Maharashtra                   10839
# ...

# %%
df9=df9.drop(labels='Total')

# %%
df9.tail()
# Out:
#                        Region  Road_accidents_NH_2015  Road_accidents_NH_2016  \
# Sl. No.
# 32       Dadra & Nagar Haveli                       0                       0
# 33                Daman & Diu                       6                       0
# 34                      Delhi                     897                     723
# 35                Lakshadweep                       0                       0
# 36                 Puducherry                     763                     874
#
#          Road_accidents_NH_2017  Road_accidents_NH_2018  Rank_in_2018
# Sl. No.
# 32                            0                       0          34.0
# 33                            9                       0          34.0
# 34                          755                     783          23.0
# 35                            0                       0          34.0
# 36                          937                     771          24.0

# %%
df9['Region'].replace(['Odisha'], ['Orissa'], inplace = True)

# %%
df9
# Out:
#                             Region  Road_accidents_NH_2015  \
# Sl. No.
# 1                   Andhra Pradesh                    8477
# 2                Arunachal Pradesh                     113
# 3                            Assam                    3353
# 4                            Bihar                    3227
# 5                     Chhattisgarh                    4058
# 6                              Goa                    1784
# 7                          Gujarat                    4897
# 8                          Haryana                    3509
# 9                 Himachal Pradesh                    1211
# 10                 Jammu & Kashmir                    1953
# 11                       Jharkhand                    2007
# 12                       Karnataka                   12705
# 13                          Kerala                    9442
# 14                  Madhya Pradesh                   11988
# 15                     Maharashtra                   10839
# ...

# %%
df=pd.merge(df,df9, on='Region')
df.head()
# Out:
#               Region  Fatal_Accidents_2015  Fatal_Accidents_2016  \
# 0     Andhra Pradesh                  8297                  8541
# 1  Arunachal Pradesh                   127                   149
# 2              Assam                  2397                  2572
# 3              Bihar                  5421                  4901
# 4       Chhattisgarh                  4082                  3908
#
#    Fatal_Accidenst_2017  drunk_drv16  drunk_drv17  drunk_drv18  \
# 0                  8060          128         2064         1345
# 1                   110           15           19           55
# 2                  2783          352          373          377
# 3                  5554          593            0           10
# 4                  4136          145           86          216
#
#    State_Fund_Accrual2016  State_Fund_Release2016  State_Fund_Accrual2017  \
# 0                  136.13                  178.13                  348.72
# ...

# %%
df.shape
# Out:
# (36, 32)

# %% [markdown]
# # ***10) Road accidents from 2015 t0 2018***

# %%
df10=pd.read_csv('Road-Accidents-2015 to 2018.csv',index_col=0)
df10.head()
# Out:
#                 States/UTs  2015  2016  2017  2018 - Number  2018 - Rank
# Sl. No.
# 1           Andhra Pradesh  2876  2689  2694           2643          7.0
# 2        Arunachal Pradesh    47    37    39             43         28.0
# 3                    Assam  1179  1190  1295           1501         15.0
# 4                    Bihar  1751  1842  2327           2801          6.0
# 5             Chhattisgarh  1063  1048  1120           1220         16.0

# %%
df10 = df10.rename(columns = {'States/UTs':'Region', '2015':'accidents_in_2015', '2016':'accidents_in_2016', '2017':'accidents_in_2017','2018 - Number':'accidents_in_2018','2018 - Rank':'Rankin2018'})
df10.head()
# Out:
#                     Region  accidents_in_2015  accidents_in_2016  \
# Sl. No.
# 1           Andhra Pradesh               2876               2689
# 2        Arunachal Pradesh                 47                 37
# 3                    Assam               1179               1190
# 4                    Bihar               1751               1842
# 5             Chhattisgarh               1063               1048
#
#          accidents_in_2017  accidents_in_2018  Rankin2018
# Sl. No.
# 1                     2694               2643         7.0
# 2                       39                 43        28.0
# 3                     1295               1501        15.0
# 4                     2327               2801         6.0
# 5                     1120               1220        16.0

# %%
df10
# Out:
#                             Region  accidents_in_2015  accidents_in_2016  \
# Sl. No.
# 1                   Andhra Pradesh               2876               2689
# 2                Arunachal Pradesh                 47                 37
# 3                            Assam               1179               1190
# 4                            Bihar               1751               1842
# 5                     Chhattisgarh               1063               1048
# 6                              Goa                127                103
# 7                          Gujarat               1913               1919
# 8                          Haryana               1605               1758
# 9                 Himachal Pradesh                290                404
# 10                 Jammu & Kashmir                312                317
# 11                       Jharkhand               1178               1112
# 12                       Karnataka               3276               3699
# ...

# %%
df10=df10.drop(labels=['Total'])
df10.tail()
# Out:
#                        Region  accidents_in_2015  accidents_in_2016  \
# Sl. No.
# 32       Dadra & Nagar Haveli                  0                  0
# 33                Daman & Diu                  5                  0
# 34                      Delhi                248                221
# 35                Lakshadweep                  0                  0
# 36                 Puducherry                142                124
#
#          accidents_in_2017  accidents_in_2018  Rankin2018
# Sl. No.
# 32                       0                  0        34.0
# 33                       5                  0        34.0
# 34                     265                258        22.0
# 35                       0                  0        34.0
# 36                     133                110        23.0

# %%
df10['Region'].replace(['Odisha'],['Orissa'],inplace=True)

# %%
df10
# Out:
#                             Region  accidents_in_2015  accidents_in_2016  \
# Sl. No.
# 1                   Andhra Pradesh               2876               2689
# 2                Arunachal Pradesh                 47                 37
# 3                            Assam               1179               1190
# 4                            Bihar               1751               1842
# 5                     Chhattisgarh               1063               1048
# 6                              Goa                127                103
# 7                          Gujarat               1913               1919
# 8                          Haryana               1605               1758
# 9                 Himachal Pradesh                290                404
# 10                 Jammu & Kashmir                312                317
# 11                       Jharkhand               1178               1112
# 12                       Karnataka               3276               3699
# ...

# %%
df = pd.merge(df,df10, on='Region')
df.head()
# Out:
#               Region  Fatal_Accidents_2015  Fatal_Accidents_2016  \
# 0     Andhra Pradesh                  8297                  8541
# 1  Arunachal Pradesh                   127                   149
# 2              Assam                  2397                  2572
# 3              Bihar                  5421                  4901
# 4       Chhattisgarh                  4082                  3908
#
#    Fatal_Accidenst_2017  drunk_drv16  drunk_drv17  drunk_drv18  \
# 0                  8060          128         2064         1345
# 1                   110           15           19           55
# 2                  2783          352          373          377
# 3                  5554          593            0           10
# 4                  4136          145           86          216
#
#    State_Fund_Accrual2016  State_Fund_Release2016  State_Fund_Accrual2017  \
# 0                  136.13                  178.13                  348.72
# ...

# %%
df = pd.merge(df7,df, on='Region')
df.head()
# Out:
#    Vehicles_From2004-2014            Region  Vehicles_From2005-2015  \
# 0                    18.7           Tripura                    14.5
# 1                    14.0  Himachal Pradesh                    13.6
# 2                    13.0             Bihar                    13.5
# 3                    12.9           Mizoram                    12.5
# 4                    12.9       Uttarakhand                    12.3
#
#    Fatal_Accidents_2015  Fatal_Accidents_2016  Fatal_Accidenst_2017  \
# 0                   158                   173                   161
# 1                  1096                  1271                  1203
# 2                  5421                  4901                  5554
# 3                    72                    70                    60
# 4                   913                   962                   942
#
#    drunk_drv16  drunk_drv17  drunk_drv18  State_Fund_Accrual2016  ...  \
# 0            5           11           28                    7.77  ...
# ...

# %%
df.shape
# Out:
# (36, 39)

# %%
df.to_csv('E:\SEM1\DAB103\Project\mearged_dataset.csv')

# %%
df = df.drop(labels = ['Rankin2018', 'Rank_in_2018', 'Vehicles_From2004-2014', 'Road_accidents_NH_2015'], axis = 1)

# %%
df.shape
# Out:
# (36, 35)

# %% [markdown]
# ## Visualization

# %%
plt.figure(figsize = (15,7))
n=36
r = np.arange(n)
width = 0.35

plt.bar(r, 'State_Fund_Accrual2016', data = df, color = 'green', label = "State fund Planned", alpha = 0.5, width = width)
plt.bar(r+width, 'State_Fund_Release2016', data = df, color = 'red', label = "State fund Released", alpha = 0.5, width = width)
plt.legend()
plt.xticks(rotation = 90, fontsize = 10)
plt.xticks(r + width/2,df['Region'])
plt.title("Funds for State roads in 2016")
plt.xlabel("Regions")
plt.ylabel("Funds in INR")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize = (15,7))
plt.bar(r, 'State_Fund_Accrual2017', data = df, color = 'green', label = "State fund Planned", alpha = 0.5, width = width)
plt.bar(r+width, 'State_Fund_Release2017', data = df, color = 'red', label = "State fund Released", alpha = 0.5, width = width)
plt.legend()
plt.xticks(rotation = 90, fontsize = 10)
plt.xticks(r + width/2,df['Region'])
plt.title("Funds for State roads in 2017")
plt.xlabel("Regions")
plt.ylabel("Funds in INR")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize = (15,7))
plt.bar(r, 'State_Fund_Accrual2018', data = df, color = 'green', label = "State fund Planned", alpha = 0.5, width = width)
plt.bar(r+width, 'State_Fund_Release2018', data = df, color = 'red', label = "State fund Released", alpha = 0.5, width = width)
plt.legend()
plt.xticks(rotation = 90, fontsize = 10)
plt.xticks(r + width/2,df['Region'])
plt.title("Funds for State roads in 2018")
plt.xlabel("Regions")
plt.ylabel("Funds in INR")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize = (15,7))
#plt.plot('Region', 'State_Fund_Release2016', data = df, label = "Released fund 2016")
plt.bar(r, 'State_Fund_Release2017', data = df, label = "Released fund 2017", width = width)
plt.bar(r+width, 'State_Fund_Release2018', data = df, label = "Released fund 2018", width = width)
plt.legend()
plt.xticks(rotation = 90)
plt.xticks(r + width/2,df['Region'])
plt.title("Funds released by states")
plt.xlabel("Regions")
plt.ylabel("Funds in INR")

plt.show()

# %%
plt.figure(figsize = (15,7))
plt.scatter('Region', 'accidents_in_2016', data = df, s = 'accidents_in_2016', alpha = 0.5)
plt.xticks(rotation = 90)
plt.title("Accidents in 2016")
plt.xlabel("Regions")
plt.ylabel("Accidents")

for i, g, in enumerate(df['accidents_in_2016']):
    plt.text(i, g, f'{g}', ha = 'center')

plt.show()

# %%
# https://www.python-graph-gallery.com/180-basic-lollipop-plot
plt.figure(figsize = (15,10))

plt.stem('Region', 'accidents_in_2016', data = df)
plt.xticks(rotation = 90)
plt.title("Accidents in 2016")
plt.xlabel("Regions")
plt.ylabel("Accidents")

for i, g, in enumerate(df['accidents_in_2016']):
    plt.text(i, g+100, f'{g}', ha = 'center')

plt.show()
# Out:
# C:\Users\RAKESH\anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   after removing the cwd from sys.path.

# %%
plt.figure(figsize = (15,10))

plt.stem('Region', 'accidents_in_2017', data = df)
plt.xticks(rotation = 90)
plt.title("Accidents in 2017")
plt.xlabel("Regions")
plt.ylabel("Accidents")

for i, g, in enumerate(df['accidents_in_2017']):
    plt.text(i, g+100, f'{g}', ha = 'center')

plt.show()
# Out:
# C:\Users\RAKESH\anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.figure(figsize = (15,10))

plt.stem('Region', 'accidents_in_2018', data = df)
plt.xticks(rotation = 90)
plt.title("Accidents in 2018")
plt.xlabel("Regions")
plt.ylabel("Accidents")

for i, g, in enumerate(df['accidents_in_2018']):
    plt.text(i, g+100, f'{g}', ha = 'center')

plt.show()
# Out:
# C:\Users\RAKESH\anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.figure(figsize = (10,7))
plt.bar('Region','NH_Projects',  data = df)
plt.title("National Highway Projects")
plt.xticks(rotation = 90)
plt.xlabel("Regions")
plt.ylabel("Number of Projects")

plt.show()

# %%
plt.figure(figsize = (10,7))
plt.bar('Region','NH_Projects_length',  data = df)
plt.title("National Highway Projects length")
plt.xticks(rotation = 90)
plt.xlabel("Regions")
plt.ylabel("Project Length in Km")

plt.show()

# %%
plt.figure(figsize = (10,7))
plt.bar('Region','NH_Project_cost',  data = df)
plt.title("National Highway Project cost")
plt.xticks(rotation = 90)
plt.xlabel("Regions")
plt.ylabel("Project cost")

plt.show()

# %%
plt.figure(figsize = (15,7))
plt.bar(r, 'accidents_in_2016', data = df, color = 'green', label = "Total accidents", alpha = 0.5, width = width)
plt.bar(r+width, 'drunk_drv16', data = df, color = 'red', label = "Drunk n drive accidents", alpha = 0.5, width = width)
plt.legend()
plt.xticks(rotation = 90, fontsize = 10)
plt.xticks(r + width/2,df['Region'])
plt.title("Total accidents and drunk n drive accidents")
plt.xlabel("Regions")
plt.ylabel("Funds in INR")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize = (15,7))
plt.bar(r, 'Fatal_Accidents_2016', data = df, color = 'green', label = "Fatal accidents in 2016", alpha = 0.5, width = width)
plt.bar(r+width, 'Fatal_Accidenst_2017', data = df, color = 'red', label = "Fatal accidents in 2017", alpha = 0.5, width = width)
plt.legend()
plt.xticks(rotation = 90, fontsize = 10)
plt.xticks(r + width/2,df['Region'])
plt.title("Fatal accidents comparison for the year 2016 and 2017")
plt.xlabel("Regions")
plt.ylabel("Fatal Accidents")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize = (15,7))
plt.bar(r-width, 'Fatal_Accidents_2015', data = df, color = 'blue', label = "Fatal accidents in 2015", alpha = 0.5, width = width)
plt.bar(r, 'Fatal_Accidents_2016', data = df, color = 'green', label = "Fatal accidents in 2016", alpha = 0.5, width = width)
plt.bar(r+width, 'Fatal_Accidenst_2017', data = df, color = 'red', label = "Fatal accidents in 2017", alpha = 0.5, width = width)
plt.legend()
plt.xticks(rotation = 90, fontsize = 10)
plt.xticks(r + width/2,df['Region'])
plt.title("Fatal accidents comparison from 2015 to 2017")
plt.xlabel("Regions")
plt.ylabel("Fatal Accidents")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
total_fund = df['State_Fund_Accrual2017'] + df['State_Fund_Accrual2018'] + df['NHfund_const2017'] + df['NHfund_const2018'] + df['NHM_Alloc17'] + df['NHM_Alloc18']
df['total_fund'] = total_fund
df.head()
# Out:
#              Region  Vehicles_From2005-2015  Fatal_Accidents_2015  \
# 0           Tripura                    14.5                   158
# 1  Himachal Pradesh                    13.6                  1096
# 2             Bihar                    13.5                  5421
# 3           Mizoram                    12.5                    72
# 4       Uttarakhand                    12.3                   913
#
#    Fatal_Accidents_2016  Fatal_Accidenst_2017  drunk_drv16  drunk_drv17  \
# 0                   173                   161            5           11
# 1                  1271                  1203           72          214
# 2                  4901                  5554          593            0
# 3                    70                    60           27           16
# 4                   962                   942           40           56
#
#    drunk_drv18  State_Fund_Accrual2016  State_Fund_Release2016  ...  \
# ...

# %%
total_fund_17 = df['State_Fund_Accrual2017'] + df['NHfund_const2017'] + df['NHM_Alloc17']
df['total_fund_17'] = total_fund_17
total_fund_18 = df['State_Fund_Accrual2018'] + df['NHfund_const2018'] + df['NHM_Alloc18']
df['total_fund_18'] = total_fund_18
df.head()
# Out:
#              Region  Vehicles_From2005-2015  Fatal_Accidents_2015  \
# 0           Tripura                    14.5                   158
# 1  Himachal Pradesh                    13.6                  1096
# 2             Bihar                    13.5                  5421
# 3           Mizoram                    12.5                    72
# 4       Uttarakhand                    12.3                   913
#
#    Fatal_Accidents_2016  Fatal_Accidenst_2017  drunk_drv16  drunk_drv17  \
# 0                   173                   161            5           11
# 1                  1271                  1203           72          214
# 2                  4901                  5554          593            0
# 3                    70                    60           27           16
# 4                   962                   942           40           56
#
#    drunk_drv18  State_Fund_Accrual2016  State_Fund_Release2016  ...  \
# ...

# %%
plt.figure(figsize = (15,7))
plt.bar(r, 'total_fund_17', data = df, color = 'green', label = "Funds allocated in 2017", alpha = 0.5, width = width)
plt.bar(r+width, 'total_fund_18', data = df, color = 'red', label = "Funds allocated in 2018", alpha = 0.5, width = width)
plt.legend()
plt.xticks(rotation = 90, fontsize = 10)
plt.xticks(r + width/2,df['Region'])
plt.title("Total funds allocation for construction and maintenance of roads")
plt.xlabel("Regions")
plt.ylabel("Funds")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize = (15,7))
plt.bar(r, 'Vehicles_From2005-2015', data = df, color = 'green', label = "Fatal accidents in 2016", alpha = 0.5, width = width)
plt.bar(r+width, 'accidents_in_2015', data = df, color = 'red', label = "Fatal accidents in 2017", alpha = 0.5, width = width)
plt.legend()
plt.xticks(rotation = 90, fontsize = 10)
plt.xticks(r + width/2,df['Region'])
plt.title("Fatal accidents comparison for the year 2016 and 2017")
plt.xlabel("Regions")
plt.ylabel("Fatal Accidents")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize = (15,7))
plt.bar(r-width, 'Vehicles_From2005-2015', data = df, color = 'blue', label = "Registered vehicle per 100Km", alpha = 0.5, width = width)
plt.bar(r, 'accidents_in_2015', data = df, color = 'green', label = "Accidents in 2015", alpha = 0.5, width = width)
plt.bar(r+width, 'accidents_in_2016', data = df, color = 'red', label = "Accidents in 2016", alpha = 0.5, width = width)
plt.legend()
plt.xticks(rotation = 90, fontsize = 10)
plt.xticks(r + width/2,df['Region'])
plt.title("Accidents in 2015 and 2016 with Vehicle density in 2015")
plt.xlabel("Regions")
plt.ylabel("Accidents and Vehivle density")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize = (15,7))
plt.bar('Region', 'Vehicles_From2005-2015', data = df, color = 'blue', label = "Registered vehicle per 100Km")
plt.xticks(rotation = 90, fontsize = 10)
plt.title("Vehicles per 100 Km")
plt.xlabel("Regions")
plt.ylabel("Vehicles")
plt.show()

# %% [markdown]
# Vehicles data for Andhra Pradesh, Punjab, Telangana, and Arunachal Pradesh was not available
